# %%
import kagglehub

dataset_100k_path = kagglehub.dataset_download("prajitdatta/movielens-100k-dataset")
#movie_dataset = kagglehub.dataset_download("rounakbanik/the-movies-dataset")
movie_500_path = kagglehub.dataset_download("tmdb/tmdb-movie-metadata")
# Out:
# ...
# 100%|██████████| 4.77M/4.77M [00:01<00:00, 2.77MB/s]
# Extracting model files...
# ...
# 100%|██████████| 8.89M/8.89M [00:02<00:00, 3.89MB/s]
# Extracting model files...

# %%
print(dataset_100k_path)
print(movie_500_path)
# Out:
# C:\Users\Admin\.cache\kagglehub\datasets\prajitdatta\movielens-100k-dataset\versions\1
# C:\Users\Admin\.cache\kagglehub\datasets\tmdb\tmdb-movie-metadata\versions\2

# %%
import os
print(os.listdir(dataset_100k_path))
print(os.listdir(movie_500_path))
# Out:
# ['ml-100k']
# ['tmdb_5000_credits.csv', 'tmdb_5000_movies.csv']

# %%
credit_path, movie_path = os.listdir(movie_500_path)

# %%
import numpy as np
import pandas as pd
import os
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics import pairwise_distances
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

from scipy.spatial.distance import cosine, correlation

#from surprise import Reader, Dataset, SVD, NormalPredictor, BaselineOnly, KNNBasic, NMF

#from surprise.model_selection import cross_validate, KFold, GridSearchCV, RandomizedSearchCV

from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.layers import Input, dot, concatenate

from keras.models import Model

from IPython.display import SVG
#from keras.utils. import model_to_dot

from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM

import gc
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 17
#      11 from scipy.spatial.distance import cosine, correlation
#      13 #from surprise import Reader, Dataset, SVD, NormalPredictor, BaselineOnly, KNNBasic, NMF
#      14
#      15 #from surprise.model_selection import cross_validate, KFold, GridSearchCV, RandomizedSearchCV
# ---> 17 from keras.models import Sequential
#      18 from keras.callbacks import ReduceLROnPlateau, EarlyStopping
#      19 from keras.layers import Input, dot, concatenate
#
# File ~\Anconda3\envs\ml-datascience\lib\site-packages\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
# ...
